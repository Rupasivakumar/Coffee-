# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("Coffe_sales .csv")

# Display first 10 rows
print(df.head(10))

# Get dataset information
print(df.info())

# Check for missing values
print(df.isnull())
# Out:
#    hour_of_day cash_type  money          coffee_name Time_of_Day Weekday  \
# 0          NaN      card   38.7                Latte     Morning     Fri
# 1          NaN      card   38.7        Hot Chocolate   Afternoon     Fri
# 2          NaN      card   38.7        Hot Chocolate   Afternoon     Fri
# 3          NaN      card   28.9            Americano   Afternoon     Fri
# 4          NaN      card   38.7                Latte   Afternoon     Fri
# 5          NaN      card   33.8  Americano with Milk   Afternoon     Fri
# 6          NaN      card   38.7        Hot Chocolate   Afternoon     Fri
# 7          NaN      card   33.8  Americano with Milk       Night     Fri
# 8          NaN      card   38.7                Cocoa       Night     Fri
# 9          NaN      card   33.8  Americano with Milk       Night     Fri
#
#   Month_name  Weekdaysort  Monthsort        Date     Time
# 0        Mar          NaN        3.0  01-03-2024  15:50.5
# ...
